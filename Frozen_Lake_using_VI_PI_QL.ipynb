# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><h1>Frozen Lake</h1></div>
# </a><a class="anchor" id="forest"></a>

# %%
import numpy as np # linear algebra
import pandas as pd
import numpy as np
import gym
from gym import wrappers
import time
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from gym.envs.toy_text.frozen_lake import generate_random_map, FrozenLakeEnv
import glob

# %%
np.random.seed(999)
twenty = generate_random_map(15)
MAPS = {
    "15x15": twenty
}

# %%
def run_process(env, policy, gamma, render = True):
    obs = env.reset()
    total_reward = 0
    step_idx = 0
    while True:
        if render:
            env.render()
        obs, reward, done , _ = env.step(int(policy[obs]))
        total_reward += (gamma ** step_idx * reward)
        step_idx += 1
        if done:
            break
    return total_reward

def evaluate_policy(env, policy, gamma , n = 100):
    scores = [run_process(env, policy, gamma, False) for _ in range(n)]
    return np.mean(scores)

def get_policy(env,v, gamma):
    policy = np.zeros(env.nS)
    for s in range(env.nS):
        q_sa = np.zeros(env.nA)
        for a in range(env.nA):
            q_sa[a] = sum([p * (r + gamma * v[s_]) for p, s_, r, _ in  env.P[s][a]])
        policy[s] = np.argmax(q_sa)
    return policy

def compute_policy(env, policy, gamma):
    v = np.zeros(env.nS)
    eps = 1e-5
    while True:
        prev_v = np.copy(v)
        for s in range(env.nS):
            policy_a = policy[s]
            v[s] = sum([p * (r + gamma * prev_v[s_]) for p, s_, r, is_done in env.P[s][policy_a]])
        if (np.sum((np.fabs(prev_v - v))) <= eps):
            break
    return v

# %%
def run_policy_iteration(env, gamma):
    policy = np.random.choice(env.nA, size=(env.nS))  
    max_iters = 200000
    desc = env.unwrapped.desc
    for i in range(max_iters):
        old_policy_v = compute_policy(env, policy, gamma)
        new_policy = get_policy(env,old_policy_v, gamma)
        if (np.all(policy == new_policy)):
            k=i+1
            break
        policy = new_policy
    return policy,k

# %%
def run_value_iteration(env, gamma):
    v = np.zeros(env.nS)  # initialize value-function
    max_iters = 100000
    eps = 1e-20
    desc = env.unwrapped.desc
    for i in range(max_iters):
        prev_v = np.copy(v)
        for s in range(env.nS):
            q_sa = [sum([p*(r + gamma*prev_v[s_]) for p, s_, r, _ in env.P[s][a]]) for a in range(env.nA)] 
            v[s] = max(q_sa)
        if (np.sum(np.fabs(prev_v - v)) <= eps):
            k=i+1
            break
    return v,k

# %%
def show_policy_map(title, policy, map_desc, color_map, direction_map):
    fig = plt.figure()
    ax = fig.add_subplot(111, xlim=(0, policy.shape[1]), ylim=(0, policy.shape[0]))
    font_size = 'x-large'
    if policy.shape[1] > 16:
        font_size = 'small'
    plt.title(title)
    for i in range(policy.shape[0]):
        for j in range(policy.shape[1]):
            y = policy.shape[0] - i - 1
            x = j
            p = plt.Rectangle([x, y], 1, 1)
            p.set_facecolor(color_map[map_desc[i,j]])
            ax.add_patch(p)

            text = ax.text(x+0.5, y+0.5, direction_map[policy[i, j]], weight='bold', size=font_size,
                           horizontalalignment='center', verticalalignment='center', color='w')
            

    plt.axis('off')
    plt.xlim((0, policy.shape[1]))
    plt.ylim((0, policy.shape[0]))
    plt.tight_layout()
    plt.show()

    return (plt)

# %%
def colors():
    return {
        b'S': '#00a8ff',
        b'F': '#bdcff0',
        b'H': 'black',
        b'G': '#136cf9',
    }


def directions():
    return {
        3: '⬆',
        2: '➡',
        1: '⬇',
        0: '⬅'
    }

# %%
environment  = 'FrozenLake-v1'
env = gym.make(environment)
save_opt = "4by4"
size = 4

env = env.unwrapped
desc = env.unwrapped.desc
time_array=[0]*15
gamma_arr=[0]*15
iters=[0]*15
list_scores=[0]*15
    
policy = np.random.choice(env.nA, size=(env.nS))  

##run_Frozen_Lake_policy_iteration("4x4")

# %%
def run_Frozen_Lake_policy_iteration(option):
    # 0 = left; 1 = down; 2 = right;  3 = up
    size = 4
    save_opt = None
    if (option == "4x4"):
        environment  = 'FrozenLake-v1'
        env = gym.make(environment)
        save_opt = "4by4"
        size = 4
    else:
        env = FrozenLakeEnv(desc=MAPS["15x15"])
        save_opt = "15by15"
        size = 15
    env = env.unwrapped
    desc = env.unwrapped.desc
    
    time_array=[0]*15
    gamma_arr=[0]*15
    iters=[0]*15
    list_scores=[0]*15

    # create data structure to save off
    columns = ['Gamma', 'Time','Average Rewards','Iterations']
    data = pd.DataFrame(0.0, index=np.arange(15), columns=columns)
    
    
    
    ### POLICY ITERATION ####
    print('Frozen Lake using PI ' + option)
    
    testNum = 0
    
    for i in range(0,15):
        st=time.time()
        best_policy,k = run_policy_iteration(env, gamma = (i+0.5)/15)
        scores = evaluate_policy(env, best_policy, gamma = (i+0.5)/15)
        gamma = (i+0.5)/15
        title = 'Frozen Lake version ' + save_opt + ' Policy Map PI discount factor '+ str(gamma)
        end=time.time()
        if i == 14:
            plot = show_policy_map(title,best_policy.reshape(size,size),desc,colors(),directions())
        gamma_arr[i]=(i+0.5)/15
        list_scores[i]=np.mean(scores)
        iters[i] = k
        time_array[i]=end-st
        
        
        data['Gamma'][testNum]        =  gamma_arr[i]
        data['Time'][testNum]        =  time_array[i]
        data['Average Rewards'][testNum]   =  list_scores[i]
        data['Iterations'][testNum] =  iters[i]

        
        testNum = testNum + 1
        
        
    
    print(gamma_arr)
    plt.plot(gamma_arr, time_array)
    plt.xlabel('Gammas')
    plt.title('Frozen Lake ' + option + ' PI-Execution Time Analysis')
    plt.ylabel('Execution Time (s)')
    plt.grid()
    plt.show()

    plt.plot(gamma_arr,list_scores)
    plt.xlabel('Gammas')
    plt.ylabel('Average Rewards')
    plt.title('Frozen Lake ' + option + ' PI-Reward Analysis')
    plt.grid()
    plt.show()

    plt.plot(gamma_arr,iters)
    plt.xlabel('Gammas')
    plt.ylabel('Iterations to Converge')
    plt.title('Frozen Lake ' + option + ' PI-Convergence Analysis')
    plt.grid()
    plt.show()
    
    
    
    plt.plot(list_scores,iters)
    plt.xlabel('Average Rewards')
    plt.ylabel('Iterations')
    plt.xticks(rotation=45)
    plt.title('Frozen Lake (PI) ' + option + ' states  - Rewards vs Iterations')
    plt.grid()
    plt.show()
    
    plt.plot(gamma_arr,list_scores)
    plt.xlabel('Gammas')
    plt.ylabel('Average Rewards')
    plt.title('Frozen Lake (PI) ' + option + ' states  - Rewards vs Gammas')
    plt.grid()
    plt.show()
    
    
    
    return data

# %%
def run_Frozen_Lake_value_iteration(option):
    # 0 = left; 1 = down; 2 = right;  3 = up
    size = 4
    save_opt = None
    if (option == "4x4"):
        environment  = 'FrozenLake-v1'
        env = gym.make(environment)
        save_opt = "4by4"
        size = 4
    else:
        env = FrozenLakeEnv(desc=MAPS["15x15"])
        save_opt = "15by15"
        size = 15
    env = env.unwrapped
    desc = env.unwrapped.desc
    time_array=[0]*15
    gamma_arr=[0]*15
    iters=[0]*15
    list_scores=[0]*15
    
    # create data structure to save off
    columns = ['Gamma', 'Time','Average Rewards','Iterations']
    data = pd.DataFrame(0.0, index=np.arange(15), columns=columns)
    
    
    
    ### VALUE ITERATION ###
    print('Frozen Lake using VI ' + option)
    best_vals=[0]*15
    
    testNum = 0
    
    
    for i in range(0,15):
        st=time.time()
        best_value,k = run_value_iteration(env, gamma = (i+0.5)/15)
        policy = get_policy(env,best_value, gamma = (i+0.5)/15)
        policy_score = evaluate_policy(env, policy, gamma=(i+0.5)/15, n=1000)
        gamma = (i+0.5)/15
        title = 'Frozen Lake version ' + save_opt + ' Policy Map VI discount factor '+ str(gamma)
        end=time.time()
        if i == 14:
            plot = show_policy_map(title,policy.reshape(size,size),desc,colors(),directions())
        gamma_arr[i]=(i+0.5)/15
        iters[i]=k
        best_vals[i] = best_value
        list_scores[i]=np.mean(policy_score)
        time_array[i]=end-st
        
        data['Gamma'][testNum]        =  gamma_arr[i]
        data['Time'][testNum]        =  time_array[i]
        data['Average Rewards'][testNum]   =  list_scores[i]
        data['Iterations'][testNum] =  iters[i]

        
        testNum = testNum + 1
        
        

    print(gamma_arr)
    plt.plot(gamma_arr, time_array)
    plt.xlabel('Gammas')
    plt.title('Frozen Lake ' + option + ' VI-Execution Time Analysis')
    plt.ylabel('Execution Time (s)')
    plt.grid()
    plt.show()

    plt.plot(gamma_arr,list_scores)
    plt.xlabel('Gammas')
    plt.ylabel('Average Rewards')
    plt.title('Frozen Lake ' + option + ' VI-Reward Analysis')
    plt.grid()
    plt.show()

    plt.plot(gamma_arr,iters)
    plt.xlabel('Gammas')
    plt.ylabel('Iterations to Converge')
    plt.title('Frozen Lake ' + option + ' VI-Convergence Analysis')
    plt.grid()
    plt.show()
    

    plt.plot(list_scores,iters)
    plt.xlabel('Average Rewards')
    plt.ylabel('Iterations')
    plt.xticks(rotation=45)
    plt.title('Frozen Lake (VI) ' + option + ' states  - Rewards vs Iterations')
    plt.grid()
    plt.show()
    
    plt.plot(gamma_arr,list_scores)
    plt.xlabel('Gammas')
    plt.ylabel('Average Rewards')
    plt.title('Frozen Lake (VI) ' + option + ' states  - Rewards vs Gammas')
    plt.grid()
    plt.show()
    
    
    return data

# %%
def run_Frozen_Lake_Q_learning(option):
    ### Q-LEARNING #####
    print('Frozen Lake using Q-Learning ' + option)
    # 0 = left; 1 = down; 2 = right;  3 = up
    size = 4
    save_opt = None
    if (option == "4x4"):
        environment  = 'FrozenLake-v1'
        env = gym.make(environment)
        save_opt = "4by4"
        size = 4
    else:
        env = FrozenLakeEnv(desc=MAPS["15x15"])
        save_opt = "15by15"
        size = 15
    st = time.time()
    reward_array = []
    iter_array = []
    size_array = []
    chunks_array = []
    averages_array = []
    time_array = []
    Q_array = []
    
    for epsilon in [0.01,0.1, 0.5]:
        Q = np.zeros((env.observation_space.n, env.action_space.n))
        rewards = []
        iters = []
        optimal=[0]*env.observation_space.n
        alpha = 0.85
        gamma = 0.95
        episodes = 30000
        
        if (option == "4x4"):
            environment  = 'FrozenLake-v1'
            env = gym.make(environment)
        else:
            env = FrozenLakeEnv(desc=MAPS["15x15"])

        env = env.unwrapped
        desc = env.unwrapped.desc
        for episode in range(episodes):
            state = env.reset()
            done = False
            t_reward = 0
            max_steps = 1000000
            for i in range(max_steps):
                if done:
                    break        
                current = state
                if np.random.rand() < (epsilon):
                    action = env.action_space.sample()
                else:
                    action = np.argmax(Q[current, :])
                state, reward, done, info = env.step(action)
                t_reward += reward
                Q[current, action] += alpha * (reward + gamma * np.max(Q[state, :]) - Q[current, action])
            #epsilon=(1-2.71**(-episode/1000))
            #print(epsilon)
            rewards.append(t_reward)
            iters.append(i)


        for k in range(env.observation_space.n):
            optimal[k]=np.argmax(Q[k, :])

        reward_array.append(rewards)
        iter_array.append(iters)
        Q_array.append(Q)

        env.close()
        end=time.time()
        time_array.append(end-st)

        # Plot results
        def chunk_list(l, n):
            for i in range(0, len(l), n):
                yield l[i:i + n]

        size = int(episodes / 50)
        chunks = list(chunk_list(rewards, size))
        averages = [sum(chunk) / len(chunk) for chunk in chunks]
        size_array.append(size)
        chunks_array.append(chunks)
        averages_array.append(averages)
        
    # print('Frozen Lake ' + option + ' - Q Learning Q Array')
    # print(Q_array)

    # print('Frozen Lake ' + option + ' - Q Learning Reward Array')
    # print(reward_array)

    plt.plot(range(0, len(reward_array[0]), size_array[0]), averages_array[0],label='epsilon=0.01')
    plt.plot(range(0, len(reward_array[1]), size_array[1]), averages_array[1],label='epsilon=0.1')
    plt.plot(range(0, len(reward_array[2]), size_array[2]), averages_array[2],label='epsilon=0.5')
    plt.legend()
    plt.xlabel('Iterations')
    plt.grid()
    plt.title('Frozen Lake ' + option + ' - Q Learning - Epsilon')
    plt.ylabel('Average Reward')
    plt.show()
    
    plt.plot([0.01,0.1,0.5],time_array)
    plt.xlabel('Epsilon Values')
    plt.grid()
    plt.title('Frozen Lake ' + option + ' - Q Learning')
    plt.ylabel('Execution Time (s)')
    plt.show()

    return iter_array,reward_array,averages_array,time_array

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Frozen Lake using PI (Small)</b>
# </div> </a><a class="anchor" id="forest_pi"></a>

# %%
data = run_Frozen_Lake_policy_iteration("4x4")
# Out:
# Frozen Lake using PI 4x4
# [0.03333333333333333, 0.1, 0.16666666666666666, 0.23333333333333334, 0.3, 0.36666666666666664, 0.43333333333333335, 0.5, 0.5666666666666667, 0.6333333333333333, 0.7, 0.7666666666666667, 0.8333333333333334, 0.9, 0.9666666666666667]

# %%
data.style \
  .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_6943c0fa_bea7_11ec_890d_085bd67499a0row0_col0,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row0_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row1_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row1_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row2_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row2_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row3_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row3_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row4_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row4_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row5_col1,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row5_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row5_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row6_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row7_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row8_col2,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row10_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row11_col3,#T_6943c0fa_bea7_11ec_890d_085bd67499a0row14_col3{
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Frozen Lake using VI (Small)</b>
# </div> </a><a class="anchor" id="forest_pi"></a>

# %%
data = run_Frozen_Lake_value_iteration("4x4")
# Out:
# Frozen Lake using VI 4x4
# [0.03333333333333333, 0.1, 0.16666666666666666, 0.23333333333333334, 0.3, 0.36666666666666664, 0.43333333333333335, 0.5, 0.5666666666666667, 0.6333333333333333, 0.7, 0.7666666666666667, 0.8333333333333334, 0.9, 0.9666666666666667]

# %%
data.style \
  .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row0_col0,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row0_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row0_col3,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row1_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row2_col1,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row2_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row3_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row4_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row5_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row6_col2,#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row7_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row0_col1{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row1_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_6bba3dac_bea7_11ec_9dd6_085bd67499a0row1_col1{
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Frozen Lake using Q-Learning (Small)</b>
# </div> </a><a class="anchor" id="forest_pi"></a>

# %%
# %%time
iter_array,reward_array,averages_array,time_array = run_Frozen_Lake_Q_learning("4x4")
# Out:
# Frozen Lake using Q-Learning 4x4
# Wall time: 23.2 s

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Frozen Lake using PI (Large)</b>
# </div> </a><a class="anchor" id="forest_pi"></a>

# %%
# %%time
data = run_Frozen_Lake_policy_iteration("15x15")
# Out:
# Frozen Lake using PI 15x15
# [0.03333333333333333, 0.1, 0.16666666666666666, 0.23333333333333334, 0.3, 0.36666666666666664, 0.43333333333333335, 0.5, 0.5666666666666667, 0.6333333333333333, 0.7, 0.7666666666666667, 0.8333333333333334, 0.9, 0.9666666666666667]
# Wall time: 3.89 s

# %%
data.style \
  .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row0_col0,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row0_col1,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row0_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row0_col3,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row1_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row1_col3,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row2_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row3_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row4_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row5_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row6_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row7_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row8_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row9_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row10_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row11_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row12_col2,#T_7bdfdb86_bea7_11ec_b1af_085bd67499a0row13_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Frozen Lake using VI (Large)</b>
# </div> </a><a class="anchor" id="forest_pi"></a>

# %%
# %%time
data = run_Frozen_Lake_value_iteration("15x15")
# Out:
# Frozen Lake using VI 15x15
# [0.03333333333333333, 0.1, 0.16666666666666666, 0.23333333333333334, 0.3, 0.36666666666666664, 0.43333333333333335, 0.5, 0.5666666666666667, 0.6333333333333333, 0.7, 0.7666666666666667, 0.8333333333333334, 0.9, 0.9666666666666667]
# Wall time: 10.8 s

# %%
data.style \
  .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_825c4722_bea7_11ec_a713_085bd67499a0row0_col0,#T_825c4722_bea7_11ec_a713_085bd67499a0row0_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row0_col3,#T_825c4722_bea7_11ec_a713_085bd67499a0row1_col1,#T_825c4722_bea7_11ec_a713_085bd67499a0row1_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row2_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row3_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row4_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row5_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row6_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row7_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row8_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row9_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row10_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row11_col2,#T_825c4722_bea7_11ec_a713_085bd67499a0row12_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_825c4722_bea7_11ec_a713_085bd67499a0row0_col1{
#             background-color:  #f5fafe;
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Frozen Lake using Q-Learning (Large)</b>
# </div> </a><a class="anchor" id="forest_pi"></a>

# %%
# %%time
iter_array,reward_array,averages_array,time_array = run_Frozen_Lake_Q_learning("15x15")
# Out:
# Frozen Lake using Q-Learning 15x15
# Wall time: 30.6 s
